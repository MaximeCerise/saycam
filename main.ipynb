# %%
import pandas as pd

# %%
df = pd.read_csv("vid1.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("vid1.csv")
#
# File ~/Desktop/saycam_byme/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/saycam_byme/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Desktop/saycam_byme/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/saycam_byme/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Desktop/saycam_byme/venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'vid1.csv'

# %%
df.head()
# Out:
#        Unnamed: 0        xmin        ymin        xmax        ymax  confidence  \
# count  356.000000  356.000000  356.000000  356.000000  356.000000  356.000000
# mean   177.500000  214.500674  211.241738  320.360643  372.383717    0.366357
# std    102.912584  174.420760  133.316899  194.608091  101.290472    0.097030
# min      0.000000    0.000000    0.000000   12.411658   40.412781    0.250090
# 25%     88.750000   55.493726  118.516344  136.931614  303.434265    0.290643
# 50%    177.500000  180.390686  225.141197  321.731216  380.875305    0.343148
# 75%    266.250000  355.934021  301.906822  485.217972  472.793648    0.411676
# max    355.000000  598.790955  455.957001  640.000000  480.000000    0.692156
#
#             class
# count  356.000000
# mean    54.853933
# std     30.415730
# min      0.000000
# 25%     36.500000
# 50%     73.000000
# 75%     73.000000
# max     79.000000

# %%
df['name'].value_counts()
# Out:
# name
# person          51
# bear             7
# umbrella         3
# donut            3
# cell phone       2
# surfboard        2
# airplane         2
# bird             2
# apple            2
# clock            1
# truck            1
# suitcase         1
# fire hydrant     1
# wine glass       1
# toothbrush       1
# snowboard        1
# bed              1
# bottle           1
# boat             1
# sports ball      1
# skis             1
# Name: count, dtype: int64

# %%
df = pd.read_csv("results_yolo5s/vid2.csv")
df['name'].value_counts()
# Out:
# name
# person          51
# bear             7
# umbrella         3
# donut            3
# cell phone       2
# surfboard        2
# airplane         2
# bird             2
# apple            2
# clock            1
# truck            1
# suitcase         1
# fire hydrant     1
# wine glass       1
# toothbrush       1
# snowboard        1
# bed              1
# bottle           1
# boat             1
# sports ball      1
# skis             1
# Name: count, dtype: int64

# %%
df
# Out:
#     Unnamed: 0        xmin       ymin        xmax        ymax  confidence  \
# 0            0  595.914856  25.437668  640.000000  233.333267    0.615034
# 1            1  439.000916  99.968201  638.752014  236.051697    0.295495
# 2            2  274.982849  63.536427  630.129272  161.718857    0.416003
# 3            3    0.004292  83.715759  101.162247  391.060730    0.550201
# 4            4  181.596863   9.255600  626.731628  469.116455    0.561727
# ..         ...         ...        ...         ...         ...         ...
# 81          81   17.195786   0.694870  301.590576   88.893539    0.389347
# 82          82  579.785522  80.809090  639.706787  270.728943    0.279703
# 83          83  410.984924   0.000000  524.687622   42.441116    0.307340
# 84          84   88.330475   0.472153  379.850311  107.085480    0.697359
# 85          85   21.818604  10.298737  637.813354  477.460541    0.433775
#
#     class       name
# 0       0     person
# 1      31  snowboard
# 2      37  surfboard
# 3       0     person
# 4       0     person
# ..    ...        ...
# 81     21       bear
# 82     74      clock
# 83     37  surfboard
# 84     30       skis
# 85      0     person
#
# [86 rows x 8 columns]

# %%
for i in range(1,6):
    print(str(i))
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
from ultralytics import YOLO
from ut import predict_yolo
from ut import predict_all_frames
import torch
import pandas as pd
from ut_plots import plot_focus_map

from extract_frames_from_vidmp4 import extraire_frames

img_path = "vid_frames/vid2_frames/frame_2.jpg"
img2 = "vid_frames/vid2_frames/frame_100.jpg"
model = YOLO('yolo11s.pt')
output = model(img2)
output.pandas()
# Out:
# image 1/1 /Users/maximemoreau/Desktop/saycam_byme/vid_frames/vid2_frames/frame_100.jpg: 480x640 2 persons, 2 remotes, 81.0ms
# Speed: 1.3ms preprocess, 81.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)

# %%
from ultralytics import YOLO
import torch
import pandas as pd
from ut_plots import plot_focus_map
from extract_frames_from_vidmp4 import extraire_frames

# Define image paths
img_path = "vid_frames/vid2_frames/frame_2.jpg"
img2 = "vid_frames/vid2_frames/frame_100.jpg"

# Load the YOLO model
model = YOLO('yolo11s.pt')

# Perform inference on the second image
output = model(img2)

# Access the detection results
results = output.pandas().xyxy[0]  # This will give you a DataFrame with detection results

# Print the results
print(results)

# If you want to visualize the results, you can use the following:
output.show()  # This will display the image with bounding boxes

# If you want to save the results to a CSV file
results.to_csv('detection_results.csv', index=False)

# If you want to plot a focus map (assuming you
# Out:
# image 1/1 /Users/maximemoreau/Desktop/saycam_byme/vid_frames/vid2_frames/frame_100.jpg: 480x640 2 persons, 2 remotes, 93.8ms
# Speed: 1.8ms preprocess, 93.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 18
#      15 output = model(img2)
#      17 # Access the detection results
# ---> 18 results = output.pandas().xyxy[0]  # This will give you a DataFrame with detection results
#      20 # Print the results
#      21 print(results)
#
# AttributeError: 'list' object has no attribute 'pandas'

# %%
from ultralytics import YOLO
import pandas as pd

# Define image paths
img_path = "vid_frames/vid2_frames/frame_2.jpg"
img2 = "vid_frames/vid2_frames/frame_100.jpg"

# Load the YOLO model
model = YOLO('yolo11s.pt')

# Perform inference on the second image
output = model(img2)

# Access the detection results
# The output is a list of Results objects (one for each image)
# For a single image, we take the first element of the list
results = output[0]

# Convert results to a pandas DataFrame
# Extract bounding boxes, confidence scores, and class labels
boxes = results.boxes.xyxy.cpu().numpy()  # Bounding boxes in [x1, y1, x2, y2] format
confidences = results.boxes.conf.cpu().numpy()  # Confidence scores
class_ids = results.boxes.cls.cpu().numpy()  # Class IDs
class_names = [results.names[int(cls_id)] for cls_id in class_ids]  # Class names

# Create a DataFrame
results_df = pd.DataFrame({
    'x1': boxes[:, 0],
    'y1': boxes[:, 1],
    'x2': boxes[:, 2],
    'y2': boxes[:, 3],
    'confidence': confidences,
    'class_id': class_ids,
    'name': class_names
})

# Print the results
print(results_df)

# Save the results to a CSV file
results_df.to_csv('detection_results.csv', index=False)

# Visualize the results
results.show()  # This will display the image with bounding boxes
# Out:
# image 1/1 /Users/maximemoreau/Desktop/saycam_byme/vid_frames/vid2_frames/frame_100.jpg: 480x640 2 persons, 2 remotes, 100.3ms
# Speed: 2.2ms preprocess, 100.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#            x1         y1          x2          y2  confidence  class_id    name
# 0  302.781677  61.249416  434.255188  182.567474    0.746981      65.0  remote
# 1    1.343842   3.499573  442.130615  477.921265    0.678375       0.0  person
# 2    0.175316   0.490814   80.715996   85.504822    0.445613      65.0  remote
# 3    2.449158   0.214325  630.352661  470.500580    0.356292       0.0  person

# %%
results_df
# Out:
#            x1         y1          x2          y2  confidence  class_id  \
# 0  302.781677  61.249416  434.255188  182.567474    0.746981      65.0
# 1    1.343842   3.499573  442.130615  477.921265    0.678375       0.0
# 2    0.175316   0.490814   80.715996   85.504822    0.445613      65.0
# 3    2.449158   0.214325  630.352661  470.500580    0.356292       0.0
#
#   class_name
# 0     remote
# 1     person
# 2     remote
# 3     person

# %%
from ut_yolo11 import predict_all_frames

frames_dir = "vid_frames/vid3_frames"
model = YOLO('yolo11s.pt')

# %%
out = predict_all_frames(model, frames_dir)
# Out:
# Traitement de : vid_frames/vid3_frames/frame_215.jpg
# Traitement de : vid_frames/vid3_frames/frame_201.jpg
# Traitement de : vid_frames/vid3_frames/frame_229.jpg
# Traitement de : vid_frames/vid3_frames/frame_361.jpg
# Traitement de : vid_frames/vid3_frames/frame_375.jpg
# Traitement de : vid_frames/vid3_frames/frame_59.jpg
# Traitement de : vid_frames/vid3_frames/frame_71.jpg
# Traitement de : vid_frames/vid3_frames/frame_349.jpg
# Traitement de : vid_frames/vid3_frames/frame_65.jpg
# Traitement de : vid_frames/vid3_frames/frame_188.jpg
# Traitement de : vid_frames/vid3_frames/frame_163.jpg
# Traitement de : vid_frames/vid3_frames/frame_177.jpg
# Traitement de : vid_frames/vid3_frames/frame_176.jpg
# Traitement de : vid_frames/vid3_frames/frame_162.jpg
# Traitement de : vid_frames/vid3_frames/frame_189.jpg
# Traitement de : vid_frames/vid3_frames/frame_348.jpg
# Traitement de : vid_frames/vid3_frames/frame_64.jpg
# Traitement de : vid_frames/vid3_frames/frame_70.jpg
# Traitement de : vid_frames/vid3_frames/frame_374.jpg
# Traitement de : vid_frames/vid3_frames/frame_58.jpg
# Traitement de : vid_frames/vid3_frames/frame_360.jpg
# Traitement de : vid_frames/vid3_frames/frame_228.jpg
# Traitement de : vid_frames/vid3_frames/frame_200.jpg
# Traitement de : vid_frames/vid3_frames/frame_214.jpg
# Traitement de : vid_frames/vid3_frames/frame_202.jpg
# Traitement de : vid_frames/vid3_frames/frame_216.jpg
# Traitement de : vid_frames/vid3_frames/frame_99.jpg
# Traitement de : vid_frames/vid3_frames/frame_389.jpg
# Traitement de : vid_frames/vid3_frames/frame_376.jpg
# Traitement de : vid_frames/vid3_frames/frame_362.jpg
# Traitement de : vid_frames/vid3_frames/frame_66.jpg
# Traitement de : vid_frames/vid3_frames/frame_72.jpg
# Traitement de : vid_frames/vid3_frames/frame_174.jpg
# Traitement de : vid_frames/vid3_frames/frame_160.jpg
# Traitement de : vid_frames/vid3_frames/frame_148.jpg
# Traitement de : vid_frames/vid3_frames/frame_149.jpg
# Traitement de : vid_frames/vid3_frames/frame_161.jpg
# Traitement de : vid_frames/vid3_frames/frame_175.jpg
# Traitement de : vid_frames/vid3_frames/frame_73.jpg
# Traitement de : vid_frames/vid3_frames/frame_67.jpg
# Traitement de : vid_frames/vid3_frames/frame_363.jpg
# Traitement de : vid_frames/vid3_frames/frame_377.jpg
# Traitement de : vid_frames/vid3_frames/frame_388.jpg
# Traitement de : vid_frames/vid3_frames/frame_98.jpg
# Traitement de : vid_frames/vid3_frames/frame_217.jpg
# Traitement de : vid_frames/vid3_frames/frame_203.jpg
# Traitement de : vid_frames/vid3_frames/frame_207.jpg
# Traitement de : vid_frames/vid3_frames/frame_213.jpg
# Traitement de : vid_frames/vid3_frames/frame_88.jpg
# Traitement de : vid_frames/vid3_frames/frame_63.jpg
# Traitement de : vid_frames/vid3_frames/frame_77.jpg
# Traitement de : vid_frames/vid3_frames/frame_373.jpg
# Traitement de : vid_frames/vid3_frames/frame_367.jpg
# Traitement de : vid_frames/vid3_frames/frame_159.jpg
# Traitement de : vid_frames/vid3_frames/frame_171.jpg
# Traitement de : vid_frames/vid3_frames/frame_165.jpg
# Traitement de : vid_frames/vid3_frames/frame_164.jpg
# Traitement de : vid_frames/vid3_frames/frame_170.jpg
# Traitement de : vid_frames/vid3_frames/frame_158.jpg
# Traitement de : vid_frames/vid3_frames/frame_366.jpg
# Traitement de : vid_frames/vid3_frames/frame_372.jpg
# Traitement de : vid_frames/vid3_frames/frame_76.jpg
# Traitement de : vid_frames/vid3_frames/frame_62.jpg
# Traitement de : vid_frames/vid3_frames/frame_89.jpg
# Traitement de : vid_frames/vid3_frames/frame_212.jpg
# Traitement de : vid_frames/vid3_frames/frame_206.jpg
# Traitement de : vid_frames/vid3_frames/frame_238.jpg
# Traitement de : vid_frames/vid3_frames/frame_210.jpg
# Traitement de : vid_frames/vid3_frames/frame_204.jpg
# Traitement de : vid_frames/vid3_frames/frame_358.jpg
# Traitement de : vid_frames/vid3_frames/frame_74.jpg
# Traitement de : vid_frames/vid3_frames/frame_60.jpg
# Traitement de : vid_frames/vid3_frames/frame_364.jpg
# Traitement de : vid_frames/vid3_frames/frame_48.jpg
# Traitement de : vid_frames/vid3_frames/frame_370.jpg
# Traitement de : vid_frames/vid3_frames/frame_199.jpg
# Traitement de : vid_frames/vid3_frames/frame_166.jpg
# Traitement de : vid_frames/vid3_frames/frame_172.jpg
# Traitement de : vid_frames/vid3_frames/frame_173.jpg
# Traitement de : vid_frames/vid3_frames/frame_167.jpg
# Traitement de : vid_frames/vid3_frames/frame_198.jpg
# Traitement de : vid_frames/vid3_frames/frame_371.jpg
# Traitement de : vid_frames/vid3_frames/frame_365.jpg
# Traitement de : vid_frames/vid3_frames/frame_49.jpg
# Traitement de : vid_frames/vid3_frames/frame_61.jpg
# Traitement de : vid_frames/vid3_frames/frame_359.jpg
# Traitement de : vid_frames/vid3_frames/frame_75.jpg
# Traitement de : vid_frames/vid3_frames/frame_205.jpg
# Traitement de : vid_frames/vid3_frames/frame_211.jpg
# Traitement de : vid_frames/vid3_frames/frame_239.jpg
# Traitement de : vid_frames/vid3_frames/frame_6.jpg
# Traitement de : vid_frames/vid3_frames/frame_289.jpg
# Traitement de : vid_frames/vid3_frames/frame_276.jpg
# Traitement de : vid_frames/vid3_frames/frame_262.jpg
# Traitement de : vid_frames/vid3_frames/frame_302.jpg
# Traitement de : vid_frames/vid3_frames/frame_316.jpg
# Traitement de : vid_frames/vid3_frames/frame_12.jpg
# Traitement de : vid_frames/vid3_frames/frame_100.jpg
# Traitement de : vid_frames/vid3_frames/frame_114.jpg
# Traitement de : vid_frames/vid3_frames/frame_128.jpg
# Traitement de : vid_frames/vid3_frames/frame_129.jpg
# Traitement de : vid_frames/vid3_frames/frame_115.jpg
# Traitement de : vid_frames/vid3_frames/frame_101.jpg
# Traitement de : vid_frames/vid3_frames/frame_13.jpg
# Traitement de : vid_frames/vid3_frames/frame_317.jpg
# Traitement de : vid_frames/vid3_frames/frame_303.jpg
# Traitement de : vid_frames/vid3_frames/frame_263.jpg
# Traitement de : vid_frames/vid3_frames/frame_277.jpg
# Traitement de : vid_frames/vid3_frames/frame_288.jpg
# Traitement de : vid_frames/vid3_frames/frame_7.jpg
# Traitement de : vid_frames/vid3_frames/frame_5.jpg
# Traitement de : vid_frames/vid3_frames/frame_261.jpg
# Traitement de : vid_frames/vid3_frames/frame_275.jpg
# Traitement de : vid_frames/vid3_frames/frame_249.jpg
# Traitement de : vid_frames/vid3_frames/frame_315.jpg
# Traitement de : vid_frames/vid3_frames/frame_39.jpg
# Traitement de : vid_frames/vid3_frames/frame_301.jpg
# Traitement de : vid_frames/vid3_frames/frame_329.jpg
# Traitement de : vid_frames/vid3_frames/frame_11.jpg
# Traitement de : vid_frames/vid3_frames/frame_117.jpg
# Traitement de : vid_frames/vid3_frames/frame_103.jpg
# Traitement de : vid_frames/vid3_frames/frame_102.jpg
# Traitement de : vid_frames/vid3_frames/frame_116.jpg
# Traitement de : vid_frames/vid3_frames/frame_10.jpg
# Traitement de : vid_frames/vid3_frames/frame_328.jpg
# Traitement de : vid_frames/vid3_frames/frame_300.jpg
# Traitement de : vid_frames/vid3_frames/frame_314.jpg
# Traitement de : vid_frames/vid3_frames/frame_38.jpg
# Traitement de : vid_frames/vid3_frames/frame_248.jpg
# Traitement de : vid_frames/vid3_frames/frame_274.jpg
# Traitement de : vid_frames/vid3_frames/frame_260.jpg
# Traitement de : vid_frames/vid3_frames/frame_4.jpg
# Traitement de : vid_frames/vid3_frames/frame_258.jpg
# Traitement de : vid_frames/vid3_frames/frame_264.jpg
# Traitement de : vid_frames/vid3_frames/frame_270.jpg
# Traitement de : vid_frames/vid3_frames/frame_338.jpg
# Traitement de : vid_frames/vid3_frames/frame_14.jpg
# Traitement de : vid_frames/vid3_frames/frame_310.jpg
# Traitement de : vid_frames/vid3_frames/frame_304.jpg
# Traitement de : vid_frames/vid3_frames/frame_28.jpg
# Traitement de : vid_frames/vid3_frames/frame_112.jpg
# Traitement de : vid_frames/vid3_frames/frame_106.jpg
# Traitement de : vid_frames/vid3_frames/frame_107.jpg
# Traitement de : vid_frames/vid3_frames/frame_113.jpg
# Traitement de : vid_frames/vid3_frames/frame_305.jpg
# Traitement de : vid_frames/vid3_frames/frame_29.jpg
# Traitement de : vid_frames/vid3_frames/frame_311.jpg
# Traitement de : vid_frames/vid3_frames/frame_339.jpg
# Traitement de : vid_frames/vid3_frames/frame_15.jpg
# Traitement de : vid_frames/vid3_frames/frame_271.jpg
# Traitement de : vid_frames/vid3_frames/frame_265.jpg
# Traitement de : vid_frames/vid3_frames/frame_259.jpg
# Traitement de : vid_frames/vid3_frames/frame_1.jpg
# Traitement de : vid_frames/vid3_frames/frame_3.jpg
# Traitement de : vid_frames/vid3_frames/frame_298.jpg
# Traitement de : vid_frames/vid3_frames/frame_273.jpg
# Traitement de : vid_frames/vid3_frames/frame_267.jpg
# Traitement de : vid_frames/vid3_frames/frame_17.jpg
# Traitement de : vid_frames/vid3_frames/frame_307.jpg
# Traitement de : vid_frames/vid3_frames/frame_313.jpg
# Traitement de : vid_frames/vid3_frames/frame_139.jpg
# Traitement de : vid_frames/vid3_frames/frame_105.jpg
# Traitement de : vid_frames/vid3_frames/frame_111.jpg
# Traitement de : vid_frames/vid3_frames/frame_110.jpg
# Traitement de : vid_frames/vid3_frames/frame_104.jpg
# Traitement de : vid_frames/vid3_frames/frame_138.jpg
# Traitement de : vid_frames/vid3_frames/frame_312.jpg
# Traitement de : vid_frames/vid3_frames/frame_306.jpg
# Traitement de : vid_frames/vid3_frames/frame_16.jpg
# Traitement de : vid_frames/vid3_frames/frame_266.jpg
# Traitement de : vid_frames/vid3_frames/frame_272.jpg
# Traitement de : vid_frames/vid3_frames/frame_299.jpg
# Traitement de : vid_frames/vid3_frames/frame_2.jpg
# Traitement de : vid_frames/vid3_frames/frame_294.jpg
# Traitement de : vid_frames/vid3_frames/frame_280.jpg
# Traitement de : vid_frames/vid3_frames/frame_257.jpg
# Traitement de : vid_frames/vid3_frames/frame_243.jpg
# Traitement de : vid_frames/vid3_frames/frame_323.jpg
# Traitement de : vid_frames/vid3_frames/frame_337.jpg
# Traitement de : vid_frames/vid3_frames/frame_33.jpg
# Traitement de : vid_frames/vid3_frames/frame_27.jpg
# Traitement de : vid_frames/vid3_frames/frame_121.jpg
# Traitement de : vid_frames/vid3_frames/frame_135.jpg
# Traitement de : vid_frames/vid3_frames/frame_109.jpg
# Traitement de : vid_frames/vid3_frames/frame_108.jpg
# Traitement de : vid_frames/vid3_frames/frame_134.jpg
# Traitement de : vid_frames/vid3_frames/frame_120.jpg
# Traitement de : vid_frames/vid3_frames/frame_26.jpg
# Traitement de : vid_frames/vid3_frames/frame_32.jpg
# Traitement de : vid_frames/vid3_frames/frame_336.jpg
# Traitement de : vid_frames/vid3_frames/frame_322.jpg
# Traitement de : vid_frames/vid3_frames/frame_242.jpg
# Traitement de : vid_frames/vid3_frames/frame_256.jpg
# Traitement de : vid_frames/vid3_frames/frame_281.jpg
# Traitement de : vid_frames/vid3_frames/frame_295.jpg
# Traitement de : vid_frames/vid3_frames/frame_283.jpg
# Traitement de : vid_frames/vid3_frames/frame_297.jpg
# Traitement de : vid_frames/vid3_frames/frame_240.jpg
# Traitement de : vid_frames/vid3_frames/frame_254.jpg
# Traitement de : vid_frames/vid3_frames/frame_268.jpg
# Traitement de : vid_frames/vid3_frames/frame_334.jpg
# Traitement de : vid_frames/vid3_frames/frame_18.jpg
# Traitement de : vid_frames/vid3_frames/frame_320.jpg
# Traitement de : vid_frames/vid3_frames/frame_308.jpg
# Traitement de : vid_frames/vid3_frames/frame_24.jpg
# Traitement de : vid_frames/vid3_frames/frame_30.jpg
# Traitement de : vid_frames/vid3_frames/frame_136.jpg
# Traitement de : vid_frames/vid3_frames/frame_122.jpg
# Traitement de : vid_frames/vid3_frames/frame_123.jpg
# Traitement de : vid_frames/vid3_frames/frame_137.jpg
# Traitement de : vid_frames/vid3_frames/frame_31.jpg
# Traitement de : vid_frames/vid3_frames/frame_309.jpg
# Traitement de : vid_frames/vid3_frames/frame_25.jpg
# Traitement de : vid_frames/vid3_frames/frame_321.jpg
# Traitement de : vid_frames/vid3_frames/frame_335.jpg
# Traitement de : vid_frames/vid3_frames/frame_19.jpg
# Traitement de : vid_frames/vid3_frames/frame_269.jpg
# Traitement de : vid_frames/vid3_frames/frame_255.jpg
# Traitement de : vid_frames/vid3_frames/frame_241.jpg
# Traitement de : vid_frames/vid3_frames/frame_296.jpg
# Traitement de : vid_frames/vid3_frames/frame_282.jpg
# Traitement de : vid_frames/vid3_frames/frame_9.jpg
# Traitement de : vid_frames/vid3_frames/frame_286.jpg
# Traitement de : vid_frames/vid3_frames/frame_292.jpg
# Traitement de : vid_frames/vid3_frames/frame_279.jpg
# Traitement de : vid_frames/vid3_frames/frame_245.jpg
# Traitement de : vid_frames/vid3_frames/frame_251.jpg
# Traitement de : vid_frames/vid3_frames/frame_21.jpg
# Traitement de : vid_frames/vid3_frames/frame_319.jpg
# Traitement de : vid_frames/vid3_frames/frame_35.jpg
# Traitement de : vid_frames/vid3_frames/frame_331.jpg
# Traitement de : vid_frames/vid3_frames/frame_325.jpg
# Traitement de : vid_frames/vid3_frames/frame_133.jpg
# Traitement de : vid_frames/vid3_frames/frame_127.jpg
# Traitement de : vid_frames/vid3_frames/frame_126.jpg
# Traitement de : vid_frames/vid3_frames/frame_132.jpg
# Traitement de : vid_frames/vid3_frames/frame_324.jpg
# Traitement de : vid_frames/vid3_frames/frame_330.jpg
# Traitement de : vid_frames/vid3_frames/frame_318.jpg
# Traitement de : vid_frames/vid3_frames/frame_34.jpg
# Traitement de : vid_frames/vid3_frames/frame_20.jpg
# Traitement de : vid_frames/vid3_frames/frame_250.jpg
# Traitement de : vid_frames/vid3_frames/frame_244.jpg
# Traitement de : vid_frames/vid3_frames/frame_278.jpg
# Traitement de : vid_frames/vid3_frames/frame_293.jpg
# Traitement de : vid_frames/vid3_frames/frame_287.jpg
# Traitement de : vid_frames/vid3_frames/frame_8.jpg
# Traitement de : vid_frames/vid3_frames/frame_291.jpg
# Traitement de : vid_frames/vid3_frames/frame_285.jpg
# Traitement de : vid_frames/vid3_frames/frame_252.jpg
# Traitement de : vid_frames/vid3_frames/frame_246.jpg
# Traitement de : vid_frames/vid3_frames/frame_36.jpg
# Traitement de : vid_frames/vid3_frames/frame_22.jpg
# Traitement de : vid_frames/vid3_frames/frame_326.jpg
# Traitement de : vid_frames/vid3_frames/frame_332.jpg
# Traitement de : vid_frames/vid3_frames/frame_118.jpg
# Traitement de : vid_frames/vid3_frames/frame_124.jpg
# Traitement de : vid_frames/vid3_frames/frame_130.jpg
# Traitement de : vid_frames/vid3_frames/frame_131.jpg
# Traitement de : vid_frames/vid3_frames/frame_125.jpg
# Traitement de : vid_frames/vid3_frames/frame_119.jpg
# Traitement de : vid_frames/vid3_frames/frame_333.jpg
# Traitement de : vid_frames/vid3_frames/frame_327.jpg
# Traitement de : vid_frames/vid3_frames/frame_23.jpg
# Traitement de : vid_frames/vid3_frames/frame_37.jpg
# Traitement de : vid_frames/vid3_frames/frame_247.jpg
# Traitement de : vid_frames/vid3_frames/frame_253.jpg
# Traitement de : vid_frames/vid3_frames/frame_284.jpg
# Traitement de : vid_frames/vid3_frames/frame_290.jpg
# Traitement de : vid_frames/vid3_frames/frame_234.jpg
# Traitement de : vid_frames/vid3_frames/frame_220.jpg
# Traitement de : vid_frames/vid3_frames/frame_208.jpg
# Traitement de : vid_frames/vid3_frames/frame_383.jpg
# Traitement de : vid_frames/vid3_frames/frame_93.jpg
# Traitement de : vid_frames/vid3_frames/frame_87.jpg
# Traitement de : vid_frames/vid3_frames/frame_340.jpg
# Traitement de : vid_frames/vid3_frames/frame_354.jpg
# Traitement de : vid_frames/vid3_frames/frame_78.jpg
# Traitement de : vid_frames/vid3_frames/frame_50.jpg
# Traitement de : vid_frames/vid3_frames/frame_368.jpg
# Traitement de : vid_frames/vid3_frames/frame_44.jpg
# Traitement de : vid_frames/vid3_frames/frame_181.jpg
# Traitement de : vid_frames/vid3_frames/frame_195.jpg
# Traitement de : vid_frames/vid3_frames/frame_142.jpg
# Traitement de : vid_frames/vid3_frames/frame_156.jpg
# Traitement de : vid_frames/vid3_frames/frame_157.jpg
# Traitement de : vid_frames/vid3_frames/frame_143.jpg
# Traitement de : vid_frames/vid3_frames/frame_194.jpg
# Traitement de : vid_frames/vid3_frames/frame_180.jpg
# Traitement de : vid_frames/vid3_frames/frame_369.jpg
# Traitement de : vid_frames/vid3_frames/frame_45.jpg
# Traitement de : vid_frames/vid3_frames/frame_51.jpg
# Traitement de : vid_frames/vid3_frames/frame_355.jpg
# Traitement de : vid_frames/vid3_frames/frame_79.jpg
# Traitement de : vid_frames/vid3_frames/frame_341.jpg
# Traitement de : vid_frames/vid3_frames/frame_86.jpg
# Traitement de : vid_frames/vid3_frames/frame_92.jpg
# Traitement de : vid_frames/vid3_frames/frame_382.jpg
# Traitement de : vid_frames/vid3_frames/frame_209.jpg
# Traitement de : vid_frames/vid3_frames/frame_221.jpg
# Traitement de : vid_frames/vid3_frames/frame_235.jpg
# Traitement de : vid_frames/vid3_frames/frame_223.jpg
# Traitement de : vid_frames/vid3_frames/frame_237.jpg
# Traitement de : vid_frames/vid3_frames/frame_380.jpg
# Traitement de : vid_frames/vid3_frames/frame_84.jpg
# Traitement de : vid_frames/vid3_frames/frame_90.jpg
# Traitement de : vid_frames/vid3_frames/frame_357.jpg
# Traitement de : vid_frames/vid3_frames/frame_343.jpg
# Traitement de : vid_frames/vid3_frames/frame_47.jpg
# Traitement de : vid_frames/vid3_frames/frame_53.jpg
# Traitement de : vid_frames/vid3_frames/frame_196.jpg
# Traitement de : vid_frames/vid3_frames/frame_182.jpg
# Traitement de : vid_frames/vid3_frames/frame_155.jpg
# Traitement de : vid_frames/vid3_frames/frame_141.jpg
# Traitement de : vid_frames/vid3_frames/frame_169.jpg
# Traitement de : vid_frames/vid3_frames/frame_168.jpg
# Traitement de : vid_frames/vid3_frames/frame_140.jpg
# Traitement de : vid_frames/vid3_frames/frame_154.jpg
# Traitement de : vid_frames/vid3_frames/frame_183.jpg
# Traitement de : vid_frames/vid3_frames/frame_197.jpg
# Traitement de : vid_frames/vid3_frames/frame_52.jpg
# Traitement de : vid_frames/vid3_frames/frame_46.jpg
# Traitement de : vid_frames/vid3_frames/frame_342.jpg
# Traitement de : vid_frames/vid3_frames/frame_356.jpg
# Traitement de : vid_frames/vid3_frames/frame_91.jpg
# Traitement de : vid_frames/vid3_frames/frame_85.jpg
# Traitement de : vid_frames/vid3_frames/frame_381.jpg
# Traitement de : vid_frames/vid3_frames/frame_236.jpg
# Traitement de : vid_frames/vid3_frames/frame_222.jpg
# Traitement de : vid_frames/vid3_frames/frame_226.jpg
# Traitement de : vid_frames/vid3_frames/frame_232.jpg
# Traitement de : vid_frames/vid3_frames/frame_81.jpg
# Traitement de : vid_frames/vid3_frames/frame_95.jpg
# Traitement de : vid_frames/vid3_frames/frame_385.jpg
# Traitement de : vid_frames/vid3_frames/frame_42.jpg
# Traitement de : vid_frames/vid3_frames/frame_56.jpg
# Traitement de : vid_frames/vid3_frames/frame_352.jpg
# Traitement de : vid_frames/vid3_frames/frame_346.jpg
# Traitement de : vid_frames/vid3_frames/frame_193.jpg
# Traitement de : vid_frames/vid3_frames/frame_187.jpg
# Traitement de : vid_frames/vid3_frames/frame_178.jpg
# Traitement de : vid_frames/vid3_frames/frame_150.jpg
# Traitement de : vid_frames/vid3_frames/frame_144.jpg
# Traitement de : vid_frames/vid3_frames/frame_145.jpg
# Traitement de : vid_frames/vid3_frames/frame_151.jpg
# Traitement de : vid_frames/vid3_frames/frame_179.jpg
# Traitement de : vid_frames/vid3_frames/frame_186.jpg
# Traitement de : vid_frames/vid3_frames/frame_192.jpg
# Traitement de : vid_frames/vid3_frames/frame_347.jpg
# Traitement de : vid_frames/vid3_frames/frame_353.jpg
# Traitement de : vid_frames/vid3_frames/frame_57.jpg
# Traitement de : vid_frames/vid3_frames/frame_43.jpg
# Traitement de : vid_frames/vid3_frames/frame_384.jpg
# Traitement de : vid_frames/vid3_frames/frame_390.jpg
# Traitement de : vid_frames/vid3_frames/frame_94.jpg
# Traitement de : vid_frames/vid3_frames/frame_80.jpg
# Traitement de : vid_frames/vid3_frames/frame_233.jpg
# Traitement de : vid_frames/vid3_frames/frame_227.jpg
# Traitement de : vid_frames/vid3_frames/frame_219.jpg
# Traitement de : vid_frames/vid3_frames/frame_231.jpg
# Traitement de : vid_frames/vid3_frames/frame_225.jpg
# Traitement de : vid_frames/vid3_frames/frame_96.jpg
# Traitement de : vid_frames/vid3_frames/frame_82.jpg
# Traitement de : vid_frames/vid3_frames/frame_386.jpg
# Traitement de : vid_frames/vid3_frames/frame_379.jpg
# Traitement de : vid_frames/vid3_frames/frame_55.jpg
# Traitement de : vid_frames/vid3_frames/frame_41.jpg
# Traitement de : vid_frames/vid3_frames/frame_345.jpg
# Traitement de : vid_frames/vid3_frames/frame_69.jpg
# Traitement de : vid_frames/vid3_frames/frame_351.jpg
# Traitement de : vid_frames/vid3_frames/frame_184.jpg
# Traitement de : vid_frames/vid3_frames/frame_190.jpg
# Traitement de : vid_frames/vid3_frames/frame_147.jpg
# Traitement de : vid_frames/vid3_frames/frame_153.jpg
# Traitement de : vid_frames/vid3_frames/frame_152.jpg
# Traitement de : vid_frames/vid3_frames/frame_146.jpg
# Traitement de : vid_frames/vid3_frames/frame_191.jpg
# Traitement de : vid_frames/vid3_frames/frame_185.jpg
# Traitement de : vid_frames/vid3_frames/frame_350.jpg
# Traitement de : vid_frames/vid3_frames/frame_344.jpg
# Traitement de : vid_frames/vid3_frames/frame_68.jpg
# Traitement de : vid_frames/vid3_frames/frame_40.jpg
# Traitement de : vid_frames/vid3_frames/frame_378.jpg
# Traitement de : vid_frames/vid3_frames/frame_54.jpg
# Traitement de : vid_frames/vid3_frames/frame_387.jpg
# Traitement de : vid_frames/vid3_frames/frame_83.jpg
# Traitement de : vid_frames/vid3_frames/frame_97.jpg
# Traitement de : vid_frames/vid3_frames/frame_224.jpg
# Traitement de : vid_frames/vid3_frames/frame_230.jpg
# Traitement de : vid_frames/vid3_frames/frame_218.jpg
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 out = predict_all_frames(model, frames_dir)
#
# File ~/Desktop/saycam_byme/ut_yolo11.py:45, in predict_all_frames(model_yolo11, frames_dir)
#      43 predictions = []
#      44 for frame in frames :
# ---> 45     predictions.append(predict_yolo11(model_yolo11,frame))
#      46 return predictions
#
# File ~/Desktop/saycam_byme/ut_yolo11.py:11, in predict_yolo11(model_yolo11, img)
#       7 def predict_yolo11(model_yolo11, img):
#       8     # Access the detection results
#       9     # The output is a list of Results objects (one for each image)
#      10     # For a single image, we take the first element of the list
# ---> 11     results = model(img)[0]
#      13     # Convert results to a pandas DataFrame
#      14     # Extract bounding boxes, confidence scores, and class labels
#      15     boxes = results.boxes.xyxy.cpu().numpy()  # Bounding boxes in [x1, y1, x2, y2] format
#
# NameError: name 'model' is not defined

# %%
from ut_plots import plot_focus_map

path = "results_yolov11s/vid5.csv"
plot_focus_map(path)

# %%
df = pd.read_csv(path)

# %%
len(df['name'].value_counts())
# Out:
# 25

# %%
from ut_plots import plot_focus_map

path = "results_yolo5s/vid5.csv"
plot_focus_map(path)

# %%
dff = pd.read_csv(path)

# %%
dff
# Out:
# 30

# %%
model = YOLO('yolo11s.pt')

# %%
model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): C2PSA(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): PSABlock(
#             (attn): Attention(
#               (qkv): Conv(
#                 (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (proj): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (pe): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (ffn): Sequential(
#               (0): Conv(
#                 (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#           )
#         )
#       )
#       (11): Upsample(scale_factor=2.0, mode='nearest')
#       (12): Concat()
#       (13): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (14): Upsample(scale_factor=2.0, mode='nearest')
#       (15): Concat()
#       (16): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (17): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (18): Concat()
#       (19): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (20): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (21): Concat()
#       (22): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (23): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )
